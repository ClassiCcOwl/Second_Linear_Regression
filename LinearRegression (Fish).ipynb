# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
data = pd.read_csv("Fish.csv")
data
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
data.drop("Species", axis=1, inplace=True)
data
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
df = pd.DataFrame(data)
df
# Out:
#      Weight  Length1  Length2  Length3   Height   Width
# 0     242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...      ...      ...      ...      ...     ...
# 154    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 6 columns]

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df_length1= pd.DataFrame(df , columns = ["Length1"])
df_length1.sort_values(by=["Length1"],inplace=True)
df_length1.reset_index(inplace = True, drop=True)
df_length1
plt.plot(df_length1["Length1"])
plt.show()

# %%
df_length2= pd.DataFrame(df , columns = ["Length2"])
df_length2.sort_values(by=["Length2"],inplace=True)
df_length2.reset_index(inplace = True, drop=True)
df_length2
plt.plot(df_length2["Length2"])
plt.show()

# %%
df_length3= pd.DataFrame(df , columns = ["Length3"])
df_length3.sort_values(by=["Length3"],inplace=True)
df_length3.reset_index(inplace = True, drop=True)
df_length3
plt.plot(df_length3["Length3"])
plt.show()

# %%
df_Weight= pd.DataFrame(df , columns = ["Weight"])
df_Weight.sort_values(by=["Weight"],inplace=True)
df_Weight.reset_index(inplace = True, drop=True)
df_Weight
plt.plot(df_Weight["Weight"])
plt.show()

# %%
W_max = df["Weight"].nlargest(5)
df.drop(W_max.index, axis = 0,inplace=True)
df.reset_index(inplace = True, drop=True)

# %%
l_min = df["Length2"].nsmallest(2)
df.drop(l_min.index, axis = 0,inplace=True)
df.reset_index(inplace = True, drop=True)

# %%
df_Weight= pd.DataFrame(df, columns = ["Weight"])
df_Weight.sort_values(by=["Weight"],inplace=True)
df_Weight.reset_index(inplace = True, drop=True)
df_Weight
plt.plot(df_Weight["Weight"])
plt.show()

# %%
under_30 = df[df["Weight"]<20]
df.drop(under_30.index, axis = 0,inplace=True)
df.reset_index(inplace = True, drop=True)

# %%
df_Weight= pd.DataFrame(df, columns = ["Weight"])
df_Weight.sort_values(by=["Weight"],inplace=True)
df_Weight.reset_index(inplace = True, drop=True)
df_Weight
plt.plot(df_Weight["Weight"])
plt.show()

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   138.000000  138.000000  138.000000  138.000000  138.000000  138.000000
# mean    405.952899   27.008696   29.281884   32.251449    9.662109    4.675638
# std     299.310984    7.863177    8.361305    9.134008    3.933806    1.398758
# min      32.000000   12.500000   13.700000   14.700000    3.528000    1.999200
# 25%     145.000000   20.500000   22.125000   24.125000    6.387000    3.624000
# 50%     300.000000   26.100000   28.350000   31.150000    8.386300    4.376200
# 75%     650.000000   32.700000   35.750000   39.675000   12.471000    5.586750
# max    1100.000000   48.300000   51.700000   55.100000   18.957000    8.142000

# %%
X = pd.DataFrame(df , columns = ["Length1", "Length2", "Length3", "Height", "Width"])
y = df["Weight"].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y , test_size = 0.2 , random_state = 0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
print(regressor.intercept_ , regressor.coef_)
# Out:
# [-595.52126365] [[ -1.37237057  41.95724144 -27.39710525  30.75463151  84.5647523 ]]

# %%
print("R2 Score:", metrics.r2_score(y_test, y_pred))
print("Mean Squared Error:", metrics.mean_squared_error(y_test, y_pred))
print("Mean Absoulute Error:", metrics.mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.9613985640533538
# Mean Squared Error: 3624.3014625085234
# Mean Absoulute Error: 44.58867583521961

# %%
fig ,(ax1,ax2,ax3) = plt.subplots(3 ,figsize=(5,8))
fig.tight_layout()
ax1.set_title("Length1 / Weight")
ax1.scatter(X_test.Length1, y_test)
ax1.scatter(X_test.Length1, y_pred)
ax1.grid()

ax2.set_title("Length2 / Weight")
ax2.scatter(X_test.Length2, y_test)
ax2.scatter(X_test.Length2, y_pred)
ax2.grid()

ax3.set_title("Length3 / Weight")
ax3.scatter(X_test.Length3, y_test)
ax3.scatter(X_test.Length3, y_pred)
ax3.grid()

# %%
fig ,(ax1,ax2) = plt.subplots(2 ,figsize=(5,8))
fig.tight_layout()
ax1.set_title("Height / Weight")
ax1.scatter(X_test.Height, y_test)
ax1.scatter(X_test.Height, y_pred)
ax1.grid()

ax2.set_title("Width / Weight")
ax2.scatter(X_test.Width, y_test)
ax2.scatter(X_test.Width, y_pred)
ax2.grid()

# %%
plt.scatter(y_pred, y_test)
plt.xlabel("prdiction")
plt.ylabel("real")
plt.grid()
plt.show()

# %%
compare = pd.DataFrame({"Real":y_test.flatten(), "Predict":y_pred.flatten()})
compare
# Out:
#       Real     Predict
# 0    450.0  504.010443
# 1    200.0  261.548411
# 2    714.0  735.887939
# 3    900.0  839.345872
# 4    700.0  691.723796
# 5    140.0  117.389893
# 6     78.0   58.548511
# 7     51.5  -43.851549
# 8   1100.0  919.031581
# 9    975.0  959.580458
# 10   770.0  645.028013
# 11   720.0  734.944326
# 12   260.0  318.681118
# 13   150.0  136.571265
# 14   120.0   98.958919
# 15   685.0  735.863950
# 16   180.0  213.289733
# 17   620.0  645.014082
# 18   225.0  221.762295
# 19   161.0  144.332355
# 20   700.0  693.094717
# 21    55.0  -41.996818
# 22   610.0  625.037491
# 23   300.0  372.353413
# 24   290.0  315.708138
# 25   188.0  247.170224
# 26   145.0  137.696772
# 27   390.0  452.689737
